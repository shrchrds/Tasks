# %%
import pandas as pd

# %% [markdown]
# ### 1. load this data in sql and pandas with a relation in sql(primary key & foreign key)

# %%
df_orders = pd.read_excel(r'C:\Users\pc\Downloads\Python Course\Ineuron\Pandas\Task\Superstore_USA.xlsx')

# %%
df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df_returns = pd.read_excel(r'C:\Users\pc\Downloads\Python Course\Ineuron\Pandas\Task\Superstore_USA.xlsx', sheet_name = 1)

# %%
df_returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
df_users = pd.read_excel(r'C:\Users\pc\Downloads\Python Course\Ineuron\Pandas\Task\Superstore_USA.xlsx', sheet_name = 2)

# %%
df_users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ### 3. find out how many return we have recived with a product id

# %%
df_returns
# 1634 products returned
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %% [markdown]
# ### 4. try to join order and return data both in sql and pandas

# %%
df_returns.columns
# Out:
# Index(['Order ID', 'Status'], dtype='object')

# %%
df_ord_returns = pd.merge(df_orders,df_returns, on='Order ID', how='left')

# %%
df_ord_returns
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'ship_days'],
#       dtype='object')

# %%
# df_orders.join(df_returns, on = 'Order ID')

# %% [markdown]
# ### 5. try to find out how may unique customer that we have

# %%
df_orders['Customer ID'].nunique()
# Out:
# 2703

# %%
2703 unique customer that we have.

# %% [markdown]
# ### 6.  try to find out in how many regions we are selling a product and who is manager for it

# %%
df_users.groupby('Region').sum()
# Out:
#          Manager
# Region
# Central    Chris
# East        Erin
# South        Sam
# West     William

# %% [markdown]
# ### 7. find out how many different shipment mode that we have and what is % usability of all the shipment

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df_orders['Ship Mode'].nunique()
# Out:
# 3

# %%
100*df_orders['Ship Mode'].value_counts()/len(df_orders)
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %% [markdown]
# ### 8 . Create a new coulmn and try to find out a difference between order date and shipment date

# %%
import datetime

# %%
def delivery_time(order_date, ship_date):
    return ship_date - order_date

# %%
df_orders['ship_days'] = df_orders.apply(lambda x:delivery_time(x['Order Date'], x['Ship Date']), axis=1)

# %%
df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %% [markdown]
# ### 9 . based on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
df_orders['ship_days'][df_orders['ship_days'] > '10 days']
# Out:
# 643    84 days
# 1548   11 days
# 1549   15 days
# 1678   17 days
# 1679   11 days
# 1680   28 days
# 1697   17 days
# 1698   11 days
# 1699   28 days
# 2515   92 days
# 5548   14 days
# 5673   17 days
# 5859   22 days
# 5881   24 days
# 8607   18 days
# 8609   17 days
# 8610   19 days
# 8973   19 days
# 8982   27 days
# 8983   31 days
# 8993   19 days
# 8996   27 days
# 8997   31 days
# Name: ship_days, dtype: timedelta64[ns]

# %% [markdown]
# ### 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
df_returns
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %% [markdown]
# ### 11 . Gorup by region and find out which region is more profitable

# %%
df_orders.groupby('Region')['Profit'].sum().sort_values()[-1:]
# Out:
# Region
# Central    519825.567067
# Name: Profit, dtype: float64

# %%
# Central region is most profitable

# %% [markdown]
# ### 12 . Try to find out overalll in which country we are giving more discount

# %%
df_orders.groupby('State or Province')['Discount'].sum().sort_values()[-1:]
# Out:
# State or Province
# California    52.28
# Name: Discount, dtype: float64

# %%
# for California maximum discount is given equal to 52.28 %

# %% [markdown]
# ### 13 . Give me a list of unique postal code

# %%
postal_code = df_orders['Postal Code'].unique()
[i for i in postal_code]
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %%
len([i for i in postal_code])
# Out:
# 1697

# %%
total 1697 unique postal_code

# %% [markdown]
# ### 14 . which customer segement is more profitalble find it out .

# %%
df_orders.groupby('Customer Segment')['Profit'].sum().sort_values()[-1:]
# Out:
# Customer Segment
# Corporate    505538.627783
# Name: Profit, dtype: float64

# %%
# Corporate Customer Segment is more profitalble

# %%
df_orders.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %% [markdown]
# ### 15 . try to find out the 10th most loss making product catagory .

# %%
df_orders.groupby('Product Name')['Profit'].sum().sort_values()[:10]
# Out:
# Product Name
# Okidata Pacemark 4410N Wide Format Dot Matrix Printer                            -39743.177832
# Polycom ViewStation™ ISDN Videoconferencing Unit                                 -36446.423528
# Epson DFX-8500 Dot Matrix Printer                                                -29557.665792
# Global High-Back Leather Tilter, Burgundy                                        -23236.837560
# Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table   -14874.638164
# Hoover Portapower™ Portable Vacuum                                               -14120.392820
# Large Capacity Hanging Post Binders                                              -12442.721780
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                -11541.176706
# KI Conference Tables                                                             -10066.260905
# Eldon ClusterMat Chair Mat with Cordless Antistatic Protection                    -9543.652500
# ...

# %% [markdown]
# ### 16 . Try to find out 10 top  product with highest margins

# %%
df_orders.groupby('Product Name')['Product Base Margin'].sum().sort_values(ascending=False)[:10]
# Out:
# Product Name
# Global High-Back Leather Tilter, Burgundy                                                    19.98
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                            18.33
# Bevis 36 x 72 Conference Tables                                                              16.38
# Adesso Programmable 142-Key Keyboard                                                         15.45
# Accessory36                                                                                  14.11
# Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms    13.64
# Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum                13.26
# Microsoft Internet Keyboard                                                                  13.21
# StarTAC 7760                                                                                 12.98
# ...
